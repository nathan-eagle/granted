# %% [markdown]
# # Cell to test chat_complete

# %%
import requests
import json

# URL to send the POST request to
url = "http://127.0.0.1:8080"

# Header to be sent
headers = {
    "function": "chat_complete"
}

body = "Write a grant about optical neural networks"


# Data to be sent
data = {
    "email": "brian3000@gmail.com",
    "branch": "test",
    "debug": "True",
    "body" : body
}

# Send the POST request
response = requests.post(url, json=data, headers=headers)
print(response)
print(response.text)
# Out:
# <Response [200]>
# {
#     "status": "success",
#     "response": {}
# }

# %% [markdown]
# # Cell to test web_summary

# %%
import requests
import json

# URL to send the GET request to
url = "http://127.0.0.1:8080"

# Header to be sent
params = {
    "function": "web_summary",
    "URL" : "https://seedfund.nsf.gov/topics/biological-technologies/",
    "debug" : "True",
    "reader" : "brian3000@gmail.com"
}


# Send the POST request
response = requests.get(url, params=params)
print(response)
print(response.text)
# Out:
# <Response [200]>
# No information provided

# %% [markdown]
# # Cell to test add_error

# %%
import requests
import json

# URL to send the POST request to
url = "http://127.0.0.1:8080"

# Header to be sent
headers = {
    "function": "chat_complete"
}

body = "Write a grant about optical neural networks"
body = [body for i in range(0,3000)]
body = " ".join(body)

# Data to be sent
data = {
    "email": "brian3000@gmail.com",
    "branch": "test",
    "debug": "True",
    "body" : body
}

# Send the POST request
response = requests.post(url, json=data, headers=headers)
print(response)
print(response.text)
# Out:
# <Response [200]>
# {
#     "status": "success",
#     "response": {}
# }

# %% [markdown]
# # test single shot sbir

# %%
import requests
import json

# URL to send the POST request to
url = "http://127.0.0.1:8080"

# Header to be sent
headers = {
    "function": "chat_complete"
}

page_inputs = {}

# Title
page_inputs['q1'] = '''
An AI-Based Grant Writing Assistant
'''
# Project Summary
page_inputs['q2'] = '''
This Small Business Innovation Research (SBIR) Phase I project proposes the development of an AI-based grant writing assistant designed to streamline the grant writing process for non-profit organizations and academic institutions. The assistant will employ a unique combination of language processing and data-driven methodologies to understand and adapt to the language patterns in grant proposals and identify critical success factors from historical grant data. The potential outcomes include a significant improvement in the efficiency and success rates of grant proposals, ultimately benefiting society at large.'''
# Project Description - Elevator Pitch
page_inputs['q3'] = '''
Elevator Pitch

The Motivation
Our motivation stems from the challenges faced by non-profit organizations and academic institutions in the grant writing process. The current methods are labor-intensive, time-consuming, and often result in missed opportunities due to the complexities of grant language and the inability to identify key success factors. Our proposed AI-based grant writing assistant aims to revolutionize this process, making it more efficient and effective. The successful implementation of our innovation will not only improve the success rates of grant proposals but also help organizations secure the funding they need to drive their missions forward. This will have a significant societal impact, contributing to economic growth and meeting societal needs. Additionally, the reduction in time and resources spent on grant writing can lead to environmental benefits, as less paper and energy are consumed in the process.

The Customer
Our target customers are non-profit organizations and academic institutions that are involved in the grant writing process. These entities often struggle with the complexities of grant language and the identification of key success factors, leading to missed opportunities and inefficient use of resources. Existing solutions, such as generic writing assistants, fail to address these unique challenges due to their lack of domain-specific knowledge and inability to analyze historical grant data for success patterns. With over $750 billion awarded annually in the US through grants, the market potential for our innovation is substantial.

The Value Proposition
Our AI-based grant writing assistant offers a unique combination of language processing and data-driven methodologies to understand and adapt to the language patterns in grant proposals and identify critical success factors from historical grant data. This dual approach sets us apart from existing solutions and provides a significant competitive advantage. Our innovation will streamline the grant writing process, significantly improve the success rates of grant proposals, and help organizations secure the funding they need to drive their missions forward. This will not only benefit our customers but also have a broader societal impact, contributing to economic growth and environmental sustainability.

The Innovation
Our innovation is an AI-based grant writing assistant that employs a unique combination of language processing and data-driven methodologies. It is designed to understand and adapt to the unique language patterns in grant proposals and identify and extract critical success factors from historical grant data. This is a novel and disruptive approach compared to current state-of-the-art technologies. The technical feasibility of our innovation is supported by our plan to design and develop an AI-based language processing model and a data-driven methodology, train these components with historical grant data, test their performance, and refine them based on test results. Our goals include achieving a minimum accuracy of 85% in interpreting and generating language patterns specific to grant proposals, and a minimum accuracy of 80% in identifying and extracting critical success factors from historical grant data.
'''
# Project Description - The Commercial Opportunity
page_inputs['q4'] = '''
The Commercial Opportunity

Market Analysis
Our innovation, an AI-based grant writing assistant, addresses a critical pain point for non-profit organizations and academic institutions: the complex and time-consuming process of grant writing. The current methods are labor-intensive and often result in missed opportunities due to the intricacies of the grant language and the inability to identify key success factors. If these issues are not addressed, organizations may continue to struggle with securing the funding they need to drive their missions forward.

The target market for our innovation is non-profit organizations and academic institutions that regularly engage in the grant writing process. With over $750 billion awarded annually in the US through grants, our AI-based grant writing assistant addresses a significant market need. The growth potential for this innovation is substantial, given the increasing reliance on grants for funding and the growing recognition of the importance of efficiency and effectiveness in the grant writing process.

The adoption of our innovation will be influenced by several factors, including technological advancements in AI and natural language processing, regulatory changes affecting grant allocation, and demographic shifts leading to an increase in the number of non-profit organizations and academic institutions. The ideal market entry point would be when these factors align to create a conducive environment for the adoption of our innovation.

Customer Validation and Business Model
Our target customers are non-profit organizations and academic institutions. Our business model involves providing our AI-based grant writing assistant as a subscription-based service, with pricing tiers based on the size and needs of the organization. Our customer acquisition strategies include direct sales, partnerships with industry associations, and online marketing.

We have validated the market opportunity through extensive customer discovery efforts, including interviews with non-profit executives and academic administrators, and pilot studies with select organizations. These efforts have provided strong evidence of customer interest and demand, with positive feedback on the potential of our innovation to streamline the grant writing process and improve success rates.

Competitive Analysis & Key Market Risks
The competitive landscape includes generic writing assistants and traditional grant writing services. However, these solutions lack the domain-specific knowledge and data-driven methodology that our innovation offers. Our AI-based grant writing assistant has the potential to disrupt the market by providing a more efficient and effective solution for grant proposal development.

Upon entry into the market, we anticipate that our innovation will be well-received due to its unique selling points and the strong demand for improved grant writing solutions. However, we also recognize the potential challenges, including regulatory hurdles and adoption barriers. We plan to mitigate these risks through strategic partnerships, continuous product refinement, and robust customer support.

Commercialization Strategy & Revenue Projection
The economic benefits of our innovation are substantial. By making the grant writing process more efficient and effective, we can help organizations secure the funding they need, leading to job creation, cost savings, and environmental benefits.

Our five-year revenue projection is as follows:

```
Revenue ($000)
Category	Year 1	Year 2	Year 3	Year 4	Year 5
SBIR funds	256	500	500	500	500
Subscription fees	100	300	600	1000	1500
Total	356	800	1100	1500	2000
```

To bring this innovation to market, we will need support from industry partners and investors. We plan to secure this support through networking events, industry conferences, and direct outreach. We also have contingency plans in place to ensure the continued development and commercialization of our innovation in case of unforeseen challenges.
'''
# Project Description - The Innovation/Technical Solution
page_inputs['q5'] = '''
The Technical Solution

The Technological Innovation

Our groundbreaking innovation is an AI-based grant writing assistant designed to revolutionize the grant writing process for non-profit organizations and academic institutions. This pioneering technology addresses the pain points of these entities by streamlining the grant writing process, significantly improving the success rates of grant proposals, and helping organizations secure the funding they need to drive their missions forward.

The scientific principles that underpin our innovation are rooted in artificial intelligence, specifically in the areas of natural language processing and data-driven methodologies. Our AI-based grant writing assistant is designed to understand and adapt to the unique language patterns in grant proposals. Simultaneously, our data-driven methodology identifies and extracts critical success factors from historical grant data. This dual approach is unprecedented and sets us apart from existing solutions.

Our innovation will advance the state of the art by establishing new techniques in AI-based language processing and data-driven methodologies. We intend to develop an AI-based language processing model that can accurately interpret and generate language patterns specific to grant proposals with a minimum accuracy of 85%. Additionally, we aim to demonstrate a data-driven methodology that can accurately identify and extract critical success factors from historical grant data with a minimum accuracy of 80%. This radical approach will revolutionize the grant writing process, making it more efficient and effective.

Key Technical Challenges and Risks

Scientific Risk #1: Developing an AI-based language processing model that can accurately interpret and generate language patterns specific to grant proposals is a significant challenge.
Importance:
The ability to understand and adapt to the unique language patterns in grant proposals is crucial for improving the success rates of grant proposals.
How this risk will be addressed in Phase I:
Our first technical objective is to develop an AI-based language processing model and train it with historical grant proposal data. Success will be measured by the model's ability to accurately interpret and generate language patterns specific to grant proposals with a minimum accuracy of 85%.

Scientific Risk #2: Demonstrating a data-driven methodology for identifying and extracting critical success factors from historical grant data is another significant challenge.
Importance:
Identifying and extracting critical success factors from historical grant data is essential for helping organizations secure the funding they need to drive their missions forward.
How this risk will be addressed in Phase I:
Our second technical objective is to demonstrate a data-driven methodology that can accurately identify and extract critical success factors from historical grant data with a minimum accuracy of 80%.

To establish feasibility of our concept, we propose the following Technical Objectives:

Technical Objective 1. Develop an AI-based grant writing assistant capable of understanding and adapting to the unique language patterns in grant proposals.
Acceptance Criterion: The AI assistant will accurately interpret and generate language patterns specific to grant proposals with a minimum accuracy of 85%, as verified through testing and evaluation.

Technical Objective 2. Demonstrate a data-driven methodology for identifying and extracting critical success factors from historical grant data.
Acceptance Criterion: The methodology will accurately identify and extract critical success factors from historical grant data with a minimum accuracy of 80%, as verified through testing and evaluation.

Status of the Intellectual Property

The intellectual property (IP) for our AI-based grant writing assistant is currently protected by a temporary patent application. We have conducted an informal freedom-to-operate search, which indicates that our technology does not infringe upon existing patents in the field. As we continue to develop the technology, we plan to work with our IP counsel, Jane Johnson, to further assess the patent landscape, file any necessary additional patents, and ensure that our IP is adequately protected throughout the project's development.

NSF Lineage

This project is based on the following NSF lineage:

    SciSIP: Knowledge Networks and the Dynamics of Innovation. (2014). SBE Office of Multidisciplinary Activities (SMA). Award Number: 1360058

    Accurate Linking of Grants and Topics in Science. (2015). SBE Office of Multidisciplinary Activities (SMA). Award Number: 1548907

    III: Small: Collaborative Research: Keyphrase Extraction in Document Networks. (2017). Division of Information & Intelligent Systems (IIS). Award Number: 1813571

    Indicators of Technological Emergence. (2018). SBE Office of Multidisciplinary Activities (SMA). Award Number: 1759960

NSF I-Corps Lineage

This team has not participated in an I-Corps activity.
'''
# Project Description - The Company/Team
page_inputs['q6'] = '''
The Company/Team
The Company
Our company, founded in 2022, is driven by a mission to revolutionize the grant writing process through innovative and affordable AI-based solutions. We are pioneers in the field, having successfully assisted in writing over 5,000 grant proposals, securing over $20,000,000 in funding within a year of our inception. This achievement earned us the 2022 Innovation Award for our breakthrough AI-based grant writing assistant technology.

Our resilience and adaptability are evident in our rapid growth and success in a short span of time. We are uniquely positioned to address the challenges in grant writing, leveraging our innovative AI technology to simplify the process and increase the success rate. Our societal impact is significant, as we enable organizations to secure necessary funding, thereby driving research, innovation, and societal development.

Company Management Team
Our team is led by Dr. Jane Smith, the Principal Investigator, who brings over 15 years of experience in natural language processing. Her passion for AI research and her commitment to innovation are the driving forces behind our groundbreaking technology.

John Doe, our Commercial Lead, is a former non-profit executive with a proven track record of securing multimillion-dollar grants. His expertise in fundraising and his understanding of the grant process are invaluable to our operations and product development.

Dr. Amy Brown, an AI innovator and research strategy consultant, brings over two decades of experience in academic research administration. Her role in management and administration, coupled with her insights into IP protection plans and regulatory input, ensure our product's success and adoption in the market.

Our advisory board includes industry-leading experts in grant management and AI technology, providing strategic guidance and business development insights.

Company Vision, Impact, and Revenue History
By 2024, we envision being a leading provider of AI-based grant writing assistance, with a 30% market share in the sector. We aim to secure over $1 billion in grant funding for our clients, thereby driving societal benefits through research and innovation.

The SBIR effort fits seamlessly into our operations, driving growth and innovation. Our revenue has grown from $0 in 2022 to $2 million in 2023, thanks to a mix of private investment and government grants. This financial growth demonstrates our sustainability and potential for future revenue generation.

Collaborators and Consultants
We have partnered with XYZ University for research and development, with Professor John McCarthy, the 'Father of Artificial Intelligence', as our chief technical consultant. His expertise adds immense value to our product development and innovation.

We also collaborate with the Center for Trustworthy AI, ensuring that our technology is trustworthy, safe, and reliable. This collaboration contributes significantly to our project's success and the societal impact of our innovation.

We are actively pursuing relevant partnerships to further enhance our product and its impact on the grant writing process.
'''
# Project Description - Technical Discussion and R&D Plan
page_inputs['q7'] = '''
Intellectual Merits: Technical Discussion and R&D Plan
Preliminary Work

Our team has made significant strides in the development of an AI-based grant writing assistant. We have built a small-scale prototype of the AI system, which has shown promising results in understanding and generating language patterns specific to grant proposals. This initial work has helped us understand key factors affecting the performance of the AI system, such as optimal operating conditions and algorithm selection. We have filed a provisional patent application for our AI-based grant writing assistant technology and published our early findings in a peer-reviewed journal, showcasing the potential benefits of the AI system over conventional grant writing methods.

The progress made so far demonstrates the potential of our AI-based grant writing assistant and lays a solid foundation for the proposed R&D plan. Our next steps include scaling up the technology and conducting further tests to validate its real-world performance.

Technical Objective 1: Develop an AI-based grant writing assistant capable of understanding and adapting to the unique language patterns in grant proposals
Acceptance Criterion: The AI assistant will accurately interpret and generate language patterns specific to grant proposals with a minimum accuracy of 85%, as verified through testing and evaluation.
i. Rationale
The development of an AI-based grant writing assistant is a critical step in revolutionizing the grant writing process. This technical objective is significant as it forms the core functionality of the AI assistant. The chosen acceptance criterion ensures the AI assistant is effective and reliable, meeting the demands of our target customers - non-profit organizations and academic institutions.

ii. Experimental Design & Methods
The tasks involved in achieving this objective include designing and developing the AI-based language processing model, training the model with historical grant proposal data, testing the model's ability, refining and optimizing the model, and conducting a final evaluation. Each task will be performed sequentially, with data collection at each stage. The project manager, [Project Manager Team Member], will oversee data collection. No special equipment is needed beyond standard computing hardware and software.

iii. Data Analysis & Interpretation
Data will be analyzed using machine learning algorithms to assess the model's accuracy in interpreting and generating grant-specific language patterns. The data will determine if the objective has been met by comparing the model's output with the acceptance criterion.

iv. Potential Pitfalls / Alternative Approaches
Potential risks include insufficient training data and unexpected model behavior. In such cases, we will source additional data and refine the model's algorithms. We will also consider alternative approaches such as using different machine learning algorithms or incorporating additional features into the model.

v. Expected Outcomes
Upon achieving this objective, the AI assistant will be capable of understanding and generating grant-specific language patterns. This will significantly enhance the overall project by providing a reliable tool for grant writing.

Technical Objective 2: Demonstrate a data-driven methodology for identifying and extracting critical success factors from historical grant data
Acceptance Criterion: The methodology will accurately identify and extract critical success factors from historical grant data with a minimum accuracy of 80%, as verified through testing and evaluation.
i. Rationale
This objective is crucial as it will enable the AI assistant to provide valuable insights to users by identifying and extracting critical success factors from historical grant data. The chosen acceptance criterion ensures the methodology is effective and reliable.

ii. Experimental Design & Methods
The tasks involved in achieving this objective include developing the data-driven methodology, training the methodology with historical grant data, testing the methodology's ability, refining and optimizing the methodology, and conducting a final evaluation. Each task will be performed sequentially, with data collection at each stage. The data scientist, [Data Scientist Team Member], will oversee data collection.

iii. Data Analysis & Interpretation
Data will be analyzed using statistical methods to assess the methodology's accuracy in identifying and extracting critical success factors from historical grant data. The data will determine if the objective has been met by comparing the methodology's output with the acceptance criterion.

iv. Potential Pitfalls / Alternative Approaches
Potential risks include insufficient historical grant data and inaccurate extraction of critical success factors. In such cases, we will source additional data and refine the methodology. We will also consider alternative approaches such as using different statistical methods or incorporating additional features into the methodology.

v. Expected Outcomes
Upon achieving this objective, the AI assistant will be capable of identifying and extracting critical success factors from historical grant data. This will significantly enhance the overall project by providing valuable insights to users.

Project Development Chart

The project development chart will be created separately, as BBCode does not support the creation of Gantt charts. The chart will show the timing for each Technical Objective, the person/organization responsible for completing each Objective or critical task, and key milestones or decision points in the project timeline.
'''
# References Cited
page_inputs['q8'] = '''
References Cited

1. Brown, J., & Smith, A. (2018). Artificial Intelligence in Grant Writing: A New Approach. Journal of Nonprofit Management, 12(3), 234-248.

2. Chen, L., & Zhang, Y. (2019). Machine Learning for Text Analysis: Applications and Challenges. Journal of Computer Science and Technology, 34(2), 372-391.

3. Davis, M., & Johnson, R. (2020). Data-Driven Methodologies in Nonprofit Sector: A Case Study. Nonprofit and Voluntary Sector Quarterly, 49(1), 77-93.

4. Gupta, S., & Kumar, P. (2017). Understanding Language Patterns: A Key to Successful Grant Proposals. Journal of Technical Writing and Communication, 47(4), 459-475.

5. Lee, J., & Kim, Y. (2016). Critical Success Factors in Grant Writing: An Empirical Study. Journal of Public Administration Research and Theory, 26(3), 551-563.

6. Liu, X., & Wang, Z. (2020). AI-Based Writing Assistants: A Review and Future Directions. IEEE Transactions on Learning Technologies, 13(1), 184-198.

7. Patel, N., & Shah, M. (2019). Statistical Methods for Data Analysis in Grant Proposal Evaluation. Journal of the Operational Research Society, 70(2), 315-327.

8. Thompson, B., & Williams, R. (2018). The Role of AI in Revolutionizing Grant Writing Process. Nonprofit Management & Leadership, 29(1), 123-137.

9. U.S. Patent No. 10,123,456. (2020). AI-Based Grant Writing Assistant. U.S. Patent and Trademark Office.

10. Zhang, H., & Li, J. (2017). Machine Learning Algorithms for Text Generation: A Comparative Study. Journal of Artificial Intelligence Research, 58, 567-600.
'''
# Biographical Sketches for each member of the team
page_inputs['q9'] = '''
Dr. Breanna Ramos, Project Manager

Dr. Breanna Ramos is a seasoned project manager with over 15 years of experience in managing AI and machine learning projects. She holds a Ph.D. in Computer Science from Stanford University, where she specialized in Natural Language Processing (NLP). Dr. Ramos has led several successful projects in the past, including the development of an AI-based language translation system. She has published over 20 papers in peer-reviewed journals and has been a speaker at numerous international conferences. Dr. Ramos's expertise in project management and NLP will be invaluable in overseeing the development of the AI-based grant writing assistant.

Dr. John Brown, Data Scientist

Dr. John Brown is a highly skilled data scientist with a decade of experience in data analysis and machine learning. He holds a Ph.D. in Data Science from the Massachusetts Institute of Technology, where his research focused on developing data-driven methodologies for extracting insights from large datasets. Dr. Brown has worked on several high-profile projects, including the development of a predictive analytics system for a Fortune 500 company. He has published over 15 papers in peer-reviewed journals and has been a guest lecturer at several universities. Dr. Brown's expertise in data science will be crucial in developing the data-driven methodology for identifying and extracting critical success factors from historical grant data.

Dr. Emily Johnson, AI Specialist

Dr. Emily Johnson is an AI specialist with over 12 years of experience in AI and machine learning. She holds a Ph.D. in Artificial Intelligence from the University of California, Berkeley, where she specialized in developing AI systems for language processing. Dr. Johnson has been involved in several groundbreaking projects, including the development of an AI-based speech recognition system. She has published over 25 papers in peer-reviewed journals and has been a keynote speaker at several AI conferences. Dr. Johnson's expertise in AI and language processing will be instrumental in developing the AI-based language processing model for the grant writing assistant.
'''
# Collaborators & Other Affiliations Information
page_inputs['q10'] = '''
Collaborators & Other Affiliations Information

1. Principal Investigator: Dr. John Doe
   Affiliation: XYZ University
   Role: Dr. Doe, a renowned expert in AI and machine learning, will oversee the overall project, ensuring the objectives are met within the stipulated timeline. He will also be responsible for the development and optimization of the AI-based language processing model.

2. Co-Investigator: Dr. Jane Smith
   Affiliation: ABC Non-profit Organization
   Role: Dr. Smith, with her extensive experience in grant writing and management, will provide critical insights into the unique language patterns in grant proposals. She will also assist in the testing and evaluation of the AI assistant.

3. Data Scientist: Mr. Richard Roe
   Affiliation: XYZ University
   Role: Mr. Roe will be responsible for developing the data-driven methodology for identifying and extracting critical success factors from historical grant data. He will also oversee data collection and analysis.

4. Project Manager: Ms. Mary Major
   Affiliation: XYZ University
   Role: Ms. Major will manage the project, ensuring tasks are completed on time and within budget. She will also oversee data collection for the development and testing of the AI-based language processing model.

5. Collaborating Organization: DEF Tech Company
   Role: DEF Tech Company, a leading AI technology firm, will provide technical support and resources for the project. They will also assist in scaling up the technology and conducting real-world performance tests.

6. Advisory Board:
   - Prof. Paul Proctor, XYZ University
   - Dr. Dana Davis, ABC Non-profit Organization
   - Mr. Mike Minor, DEF Tech Company
   Role: The advisory board, comprising experts from academia, non-profit sector, and industry, will provide strategic guidance and feedback throughout the project.

7. Other Affiliations:
   - GHI Foundation: The GHI Foundation, a major funder of research in AI and machine learning, has expressed interest in the project and may provide additional funding and resources.
   - JKL University: JKL University has agreed to provide access to their extensive database of historical grant data for the project.

All collaborators and affiliations have been informed of their roles and have agreed to participate in the project. Their expertise and resources will significantly contribute to the successful completion of the project.
'''
# Facilities, Equipment and Other Resources
page_inputs['q11'] = '''
Facilities, Equipment and Other Resources

Facilities

Our organization is housed in a state-of-the-art facility that provides an ideal environment for the development and testing of our AI-based grant writing assistant. The facility includes a dedicated research and development lab, equipped with high-speed internet and secure servers for data storage and processing. The lab also includes a meeting room for team discussions and brainstorming sessions.

In addition to the R&D lab, our facility also includes office spaces for our project manager, data scientists, and other team members. These spaces are equipped with modern workstations and necessary software tools for project management, data analysis, and AI model development.

Equipment

Our team has access to high-performance computing resources necessary for the development and testing of the AI-based grant writing assistant. This includes multiple servers with high-speed processors and large memory capacities, which are essential for training and testing AI models.

We also have access to a variety of software tools for AI development, including TensorFlow, PyTorch, and Keras for building and training AI models, and Python and R for data analysis and visualization.

Other Resources

Our organization has access to a large database of historical grant proposal data, which will be used for training the AI model. This data is stored securely on our servers and is regularly updated to ensure its relevance and accuracy.

We also have a strong network of partners in the non-profit and academic sectors, who will provide valuable feedback and insights during the development and testing of the AI-based grant writing assistant.

In addition, our team includes experienced data scientists and AI developers, who bring a wealth of knowledge and expertise to the project. Their skills and experience will be instrumental in achieving the project's technical objectives.

In conclusion, our organization has the necessary facilities, equipment, and other resources to successfully carry out the proposed R&D plan for the AI-based grant writing assistant.
'''

body = "This grant is an NSF SBIR."
for counter in range(1,10):
    body += "qinput: " 
    body += page_inputs['q'+str(counter)]
  
# Data to be sent
data = {
    "email": "brian3000@gmail.com",
    "branch": "35zp",
    "debug": "True",
    "body" : body,
    "model_title" : "NSF SBIR",
    "project_id" : '1684180443986x590840930442674200'
}

# Send the POST request
response = requests.post(url, json=data, headers=headers)
print(response)
print(response.text)
# Out:
# ---------------------------------------------------------------------------
# ConnectionResetError                      Traceback (most recent call last)
# File ~\anaconda3\lib\site-packages\urllib3\connectionpool.py:703, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     702 # Make the request on the httplib connection object.
# --> 703 httplib_response = self._make_request(
#     704     conn,
#     705     method,
#     706     url,
#     707     timeout=timeout_obj,
#     708     body=body,
#     709     headers=headers,
#     710     chunked=chunked,
#     711 )
#     713 # If we're going to release the connection in ``finally:``, then
#     714 # the response doesn't need to know about the connection. Otherwise
#     715 # it will also try to release it and we'll have a double-release
#     716 # mess.
#
# ...

# %% [markdown]
# # Code to test evaluation

# %%
import requests
import json

# URL to send the POST request to
url = "http://127.0.0.1:8080"

# Header to be sent
headers = {
    "function": "nsf_complete"
}


body = '''
qinput:
[b]PROJECT PITCH[/b]

[b]The Technology Innovation[/b]

The current landscape of grant writing is fraught with challenges. Non-profit organizations and academic institutions often struggle with the time-consuming and complex process of crafting compelling grant proposals. Existing technologies offer limited assistance, often failing to adapt to the unique language patterns and critical success factors inherent in successful grant proposals. This gap in the market presents an opportunity for a novel, AI-based solution.

Our innovation, an AI-based grant writing assistant, is a pioneering solution designed to streamline the grant writing process. This assistant leverages advanced natural language processing and machine learning techniques to adapt to the specialized language patterns in grant proposals and extract critical success factors from historical grant data. This technology is unproven in the grant writing domain, making it a groundbreaking solution.

The AI-based grant writing assistant addresses the pain points of time-consuming proposal creation and low success rates. Current technologies lack the ability to adapt to the unique language patterns in grant proposals and fail to identify and extract critical success factors, leading to suboptimal proposals. Our innovation overcomes these limitations, offering a more efficient and effective solution.

The broader implications of our innovation are significant. By streamlining the grant writing process, we can help non-profit organizations and academic institutions secure much-needed funding, thereby enabling them to make a greater impact in their respective fields. This aligns with NSF's mission of advancing science and engineering in service of society.

The development of our AI-based grant writing assistant involves significant R&D work, including the development of a context-aware language processing system and data-driven methodologies for identifying and extracting critical success factors from historical grant data. 

[b]The Technical Objectives and Challenges[/b]

A successful Phase I project outcome would involve the development and integration of a context-aware language processing system and data-driven methodologies into our AI-based grant writing assistant. This would demonstrate the assistant's ability to adapt to unique language patterns and extract critical success factors, thereby addressing the pain points introduced in the Technology Innovation section.

The technical work involved in achieving this outcome includes researching and identifying unique language patterns in grant proposals, designing and developing the context-aware language processing system, and developing data-driven methodologies for identifying and extracting critical success factors. These tasks present significant challenges, including the need to collect and analyze a large volume of historical grant data and the complexity of integrating the developed systems and methodologies into the AI-based grant writing assistant.

Despite these challenges, our project aligns with the R&D definition and NSF SBIR STTR Program objectives, as it involves high-risk, high-reward research that has the potential to transform the grant writing process.

[b]The Market Opportunity[/b]

Our innovation's end-users are non-profit organizations and academic institutions burdened by the complex grant writing process. These entities often struggle with crafting compelling grant proposals, a problem that our AI-based grant writing assistant can solve. With over $750 billion awarded annually in the US through grants, the market opportunity for our innovative solution is substantial.

[b]The Company and Team[/b]

Our company, founded in 2022, is dedicated to revolutionizing the grant writing process through innovative AI-based solutions. Our team consists of Dr. Jane Smith, a seasoned AI researcher with over 15 years in natural language processing, and John Doe, a former non-profit executive with a proven track record of securing multimillion-dollar grants. Together, they bring a unique blend of technical expertise and market knowledge to the project, ensuring its success and adoption in the market.

qinput:
[b]PROJECT SUMMARY[/b]

[b]Overview[/b]
This Small Business Innovation Research (SBIR) Phase I project proposes the development of an AI-based grant writing assistant. This innovative solution leverages advanced natural language processing and machine learning techniques to streamline the grant writing process, improving efficiency and success rates for non-profit organizations and academic institutions. The potential outcomes include a significant reduction in the time and resources required for grant proposal creation and an increase in the success rate of grant applications.

[b]Keywords[/b]
Artificial Intelligence, Natural Language Processing, Machine Learning, Grant Writing, Non-Profits, Academic Institutions

[b]Topic/Subtopic[/b]
Topic: Technology Innovation
Subtopic: An AI-based grant writing assistant

[b]Intellectual Merit[/b]
This Small Business Innovation Research Phase I project aims to revolutionize the grant writing process by developing an AI-based grant writing assistant. The assistant will utilize advanced natural language processing and machine learning techniques to adapt to the unique language patterns in grant proposals and extract critical success factors from historical grant data. The technical hurdles to be addressed include the collection and analysis of a large volume of historical grant data and the integration of the developed systems and methodologies into the AI-based grant writing assistant. The goals of the proposed R&D include the development and integration of a context-aware language processing system and data-driven methodologies into the assistant, demonstrating its ability to streamline the grant writing process and improve success rates.

[b]Broader/Commercial Impact[/b]
Commercial impact: The proposed AI-based grant writing assistant addresses a significant market opportunity, with over $750 billion awarded annually in the US through grants. The assistant will streamline the grant writing process for non-profit organizations and academic institutions, improving efficiency and success rates, and saving valuable resources. This will bring the innovation closer to commercialization under a sustainable business model, transforming the grant writing market and benefiting the company. Broader impacts: The commercialization of this innovation will have far-reaching societal benefits. By enabling non-profit organizations and academic institutions to secure much-needed funding more efficiently and effectively, the assistant will support their efforts to make a greater impact in their respective fields, thereby advancing science and engineering in service of society.


[b]PROJECT DESCRIPTION[/b]
qinput:
[b]1. ELEVATOR PITCH[/b]

```[b]The Motivation[/b]
Our company is driven by the desire to revolutionize the grant writing process, a task that often poses significant challenges for non-profit organizations and academic institutions. The current landscape of grant writing is time-consuming and complex, with existing technologies offering limited assistance. Our motivation is to bridge this gap with an AI-based grant writing assistant that adapts to the unique language patterns in grant proposals and extracts critical success factors from historical grant data. If successful, this innovation will streamline the grant writing process, significantly reducing the time and resources required for proposal creation and increasing the success rate of grant applications. This aligns with NSF's mission of advancing science and engineering in service of society, as it enables these entities to secure much-needed funding and make a greater impact in their respective fields.

[b]The Customer[/b]
Our target customers are non-profit organizations and academic institutions burdened by the complex grant writing process. These entities often struggle with crafting compelling grant proposals, a problem that our AI-based grant writing assistant can solve. Existing solutions lack the ability to adapt to the unique language patterns in grant proposals and fail to identify and extract critical success factors, leading to suboptimal proposals. With over $750 billion awarded annually in the US through grants, the market opportunity for our innovative solution is substantial.

[b]The Value Proposition[/b]
Our AI-based grant writing assistant offers a unique value proposition. It leverages advanced natural language processing and machine learning techniques to adapt to the unique language patterns in grant proposals and extract critical success factors from historical grant data. This not only streamlines the grant writing process but also improves the success rate of grant applications. Unlike existing solutions, our innovation is designed to overcome the limitations of the current grant writing process, offering a more efficient and effective solution. The societal value generated by our innovation is significant, as it enables non-profit organizations and academic institutions to secure much-needed funding more efficiently and effectively, thereby supporting their efforts to make a greater impact in their respective fields.

[b]The Innovation[/b]
Our innovation is an AI-based grant writing assistant that revolutionizes the grant writing process. It utilizes advanced natural language processing and machine learning techniques to adapt to the unique language patterns in grant proposals and extract critical success factors from historical grant data. This is a novel approach in the grant writing domain, making it a groundbreaking solution. The technical feasibility of our innovation is supported by the expertise of our team, which includes a seasoned AI researcher and a former non-profit executive with a proven track record of securing multimillion-dollar grants. The goals of our R&D include the development and integration of a context-aware language processing system and data-driven methodologies into the assistant, demonstrating its ability to streamline the grant writing process and improve success rates.```


qinput:
[b]2. COMMERCIAL OPPORTUNITY[/b]

[b]Market Analysis[/b]

Our AI-based grant writing assistant addresses the pressing needs of non-profit organizations and academic institutions. These entities often grapple with the time-consuming and complex process of crafting compelling grant proposals. The consequences of not addressing these issues are significant, including missed funding opportunities and reduced impact in their respective fields.

The target market for our innovation is the non-profit and academic sector. With over $750 billion awarded annually in the US through grants, the addressable market size is substantial. The growth potential is also promising, given the increasing reliance on grants for funding and the lack of efficient solutions in the market.

The business economics of our innovation are driven by the need for efficiency and effectiveness in the grant writing process. Market drivers include the increasing demand for grant funding and the growing recognition of the benefits of AI-based solutions. Technological advancements in natural language processing and machine learning also present opportunities for market entry and growth.

[b]Customer Validation and Business Model[/b]

Our target customers are non-profit organizations and academic institutions. Our business model involves a subscription-based pricing strategy, with revenue streams from monthly or annual subscriptions. Sales channels include direct sales and online marketing, with customer acquisition strategies focusing on targeted marketing and partnerships with industry associations.

Market validation efforts have included customer interviews and pilot studies. Feedback from these efforts has been overwhelmingly positive, with customers expressing a high level of interest in our innovation. We have also received several market validation letters from potential customers, further confirming the demand for our solution.

[b]Competitive Analysis & Key Market Risks[/b]

The competitive landscape for our innovation includes existing grant writing software and services. However, these solutions lack the ability to adapt to the unique language patterns in grant proposals and fail to identify and extract critical success factors, presenting an opportunity for our AI-based grant writing assistant to disrupt the market.

Upon entry into the market, we anticipate changes to the competitive landscape, including potential competition from other AI-based solutions. However, our first-mover advantage and proprietary technology position us well for success. Key market risks include regulatory hurdles and adoption barriers, which we plan to mitigate through ongoing customer engagement and education.

[b]Commercialization Strategy & Revenue Projection[/b]

The economic benefits of our innovation are significant. By streamlining the grant writing process, we can help non-profit organizations and academic institutions secure much-needed funding, thereby enabling them to make a greater impact in their respective fields. We project a five-year revenue of $50 million, based on conservative estimates of market penetration and subscription pricing.

To bring our innovation to market, we will need support from industry partners and investors. We plan to secure this support through strategic partnerships, licensing opportunities, and fundraising efforts. In case of unforeseen challenges, we have contingency plans in place, including alternative funding sources and potential pivots in our business model.


qinput:
[b]3. THE TECHNICAL SOLUTION[/b]

[b]The Technological Innovation[/b]

Our innovation is an AI-based grant writing assistant that leverages advanced natural language processing (NLP) and machine learning techniques to revolutionize the grant writing process. The assistant adapts to the unique language patterns in grant proposals and extracts critical success factors from historical grant data. This groundbreaking approach addresses the pain points felt by non-profit organizations and academic institutions, which often struggle with the complex and time-consuming task of crafting compelling grant proposals.

The scientific principles underpinning our innovation are rooted in the fields of artificial intelligence, machine learning, and natural language processing. Our assistant uses NLP to understand and adapt to the unique language patterns in grant proposals, while machine learning techniques are employed to identify and extract critical success factors from historical grant data. This combination of technologies enables our assistant to generate high-quality grant proposals that significantly increase the success rate of grant applications.

Our innovation will advance the state of the art by establishing new techniques and processes in the grant writing domain. We intend to develop a context-aware language processing system that can adapt to the unique language patterns in grant proposals, a feature that is currently lacking in existing solutions. Additionally, we plan to demonstrate new data-driven methodologies for identifying and extracting critical success factors from historical grant data. These methodologies will advance the state-of-the-art in machine learning models and their applicability in the grant writing domain.

[b]Key Technical Challenges and Risks[/b]

[b]Scientific Risk #1:[/b] Developing a context-aware language processing system that can adapt to the unique language patterns in grant proposals is a pioneering endeavor. The success of this endeavor would result in a revolutionary tool that significantly streamlines the grant writing process.
[b]Importance:[/b]
The ability to adapt to the unique language patterns in grant proposals is crucial for crafting compelling grant applications. Overcoming this challenge will significantly improve the efficiency and effectiveness of the grant writing process.
[b]How this risk will be addressed in Phase I:[/b]
The first technical objective is to develop a context-aware language processing system for the AI-based grant writing assistant. Success will be measured by the system's ability to adapt to unique language patterns, as verified through testing and statistical analysis.

[b]Scientific Risk #2:[/b] Demonstrating new data-driven methodologies for identifying and extracting critical success factors from historical grant data is an unprecedented task. The success of this task would result in a landmark advancement in the application of machine learning models in the grant writing domain.
[b]Importance:[/b]
Identifying and extracting critical success factors from historical grant data is key to improving the success rate of grant applications. Overcoming this challenge will significantly enhance the effectiveness of the grant writing process.
[b]How this risk will be addressed in Phase I:[/b]
The second technical objective is to demonstrate new data-driven methodologies for identifying and extracting critical success factors from historical grant data. Success will be measured by the methodologies' ability to advance the state-of-the-art in machine learning models and their applicability in the grant writing domain, as verified through testing and statistical analysis.

[b]Status of the Intellectual Property[/b]

The intellectual property (IP) for our AI-based grant writing assistant is currently protected by a provisional patent application. We have conducted both formal and informal freedom-to-operate searches, which indicate that our technology does not infringe upon existing patents in the field. As we continue to develop the technology, we plan to work with our IP counsel, [Your IP Counsel's Name], to further assess the patent landscape, file any necessary additional patents, and ensure that our IP is adequately protected throughout the project's development.

[b]NSF Lineage[/b]

This project is based on the following NSF lineage:

- SciSIP: Knowledge Networks and the Dynamics of Innovation. (2014). SBE Office of Multidisciplinary Activities (SMA). Award Number: 1360058
- Accurate Linking of Grants and Topics in Science. (2015). SBE Office of Multidisciplinary Activities (SMA). Award Number: 1548907
- III: Small: Collaborative Research: Keyphrase Extraction in Document Networks. (2017). Division of Information & Intelligent Systems (IIS). Award Number: 1813571
- Indicators of Technological Emergence. (2018). SBE Office of Multidisciplinary Activities (SMA). Award Number: 1759960

[b]NSF I-Corps Lineage[/b]

This team has not participated in an I-Corps activity.


qinput:
[b]4. THE COMPANY/TEAM[/b]

[b]The Company[/b]

In the heart of the digital revolution, our company, founded in 2022, stands as a beacon of innovation. Our mission is to revolutionize the grant writing process by offering innovative and affordable AI-based solutions. We envision being a leading provider of AI-based grant writing assistance by 2024, with a 30% market share in the sector. Our goal is to secure over $1 billion in grant funding for our clients, thus enabling countless projects to come to life and contribute to societal progress.

In just a year, we have successfully assisted in writing over 5,000 grant proposals, securing over $20,000,000 in funding. This achievement earned us the 2022 Innovation Award for our breakthrough AI-based grant writing assistant technology. Our resilience and adaptability have been key to our rapid growth and success.

Our unique positioning in the market allows us to address a critical need for efficient and effective grant writing. By leveraging AI technology, we are bringing a novel solution to the market that not only streamlines the grant writing process but also increases the chances of securing funding. This innovation has the potential to significantly impact society by enabling more projects to receive the funding they need to make a difference.

[b]Company Management Team[/b]

Our team is composed of passionate and committed individuals with a wealth of experience and expertise. Dr. Jane Smith, our Principal Investigator, is a seasoned AI researcher with over 15 years in natural language processing. Her technical expertise is instrumental in the development of our innovative AI-based grant writing assistant.

John Doe, our Commercial Lead, is a former non-profit executive with a proven track record of securing multimillion-dollar grants. His fundraising skills and experience are invaluable in guiding our clients through the grant application process.

Dr. Amy Brown, an AI innovator and research strategy consultant, brings over two decades of experience in academic research administration. Her role in management and administration ensures the smooth operation of our company.

Our team's diverse skills and experiences contribute to the success of our project and the development of our innovative solution. We are committed to revolutionizing the grant writing process and making a significant societal impact.

[b]Company Vision, Impact, and Revenue History[/b]

Looking ahead, we aim to be a leading provider of AI-based grant writing assistance by 2024. We believe our technology can secure over $1 billion in grant funding for our clients, thus enabling numerous projects that can positively impact society.

The SBIR effort fits perfectly into our existing operations, driving growth and innovation. It will allow us to further develop our AI-based grant writing assistant and expand our reach.

Our revenue has grown from $0 in 2022 to $2 million in 2023, thanks to a mix of private investment and government grants. This financial growth demonstrates our sustainability and potential for future revenue generation.

[b]Collaborators and Consultants[/b]

We are proud to collaborate with XYZ University for research and development. Professor John McCarthy, the so-called 'Father of Artificial Intelligence', serves as our chief technical consultant. His expertise adds significant value to our project.

We also collaborate with the Center for Trustworthy AI, ensuring that our technology is trustworthy, safe, and reliable. This partnership contributes to the success of our project and the development of our innovative solution.

We are actively pursuing additional partnerships that can further enhance our project and its potential impact.


qinput:
[b]5. TECHNICAL DISCUSSION and R&D PLAN[/b]

[b]Preliminary Work[/b]

Our team has already made significant strides in the development of our AI-based grant writing assistant. We have successfully constructed and tested a small-scale prototype of the assistant, which has demonstrated improved efficiency and performance compared to traditional grant writing methods. This early success has not only validated our approach but also provided us with valuable insights into the key factors that influence the performance of the assistant. These insights, which include understanding optimal operating conditions and the selection of appropriate components, will inform our future development efforts.

In addition to our prototype, we have also taken steps to protect our intellectual property. We have filed a provisional patent application for our AI-based grant writing technology, ensuring that our innovative approach is safeguarded. Furthermore, our early findings have been published in a peer-reviewed journal, showcasing the potential benefits of our assistant over conventional grant writing methods.

The preliminary work we have conducted provides a solid foundation for the proposed R&D plan outlined in this NSF SBIR grant proposal. Our next steps involve scaling up the technology and conducting additional tests to validate its performance in real-world scenarios.

[b]Technical Objective 1: Develop a context-aware language processing system for the AI-based grant writing assistant within 18 months.[/b]
[b]Acceptance Criterion:[/b] The system will be able to adapt to the unique and specialized language patterns in grant proposals, as verified through testing and statistical analysis.
[b][i]i. Rationale[/i][/b]
The development of a context-aware language processing system is a critical component of our project. This system will enable our AI assistant to understand and mimic the unique language patterns found in grant proposals, thereby increasing its effectiveness. The chosen acceptance criterion provides a measurable and relevant way to assess the system's performance, ensuring that it meets the needs of our customers.

[b][i]ii. Experimental Design & Methods[/i][/b]
Our approach to achieving this objective involves a series of tasks, including researching language patterns, designing and developing the system, integrating it into the AI assistant, testing its adaptability, and performing statistical analysis. Each task will be led by our team's lead data scientist, who will also be responsible for data collection. No special equipment is needed for data collection.

[b][i]iii. Data Analysis & Interpretation[/i][/b]
The data collected during the testing phase will be interpreted through statistical analysis to assess the system's performance. This analysis will provide insights into the system's ability to adapt to unique language patterns, thereby determining if the objective has been met.

[b][i]iv. Potential Pitfalls / Alternative Approaches[/i][/b]
Potential risks include the system not being able to fully adapt to language patterns. In case of such issues, alternative approaches such as refining the system's algorithms or using different language processing techniques will be considered.

[b][i]v. Expected Outcomes[/i][/b]
Upon achieving this objective, we expect to have a functioning AI assistant capable of understanding and mimicking grant proposal language. This will significantly advance our project, making the AI assistant more effective and increasing its potential for success.

[b]Technical Objective 2: Demonstrate new data-driven methodologies for identifying and extracting critical success factors from historical grant data within 24 months.[/b]
[b]Acceptance Criterion:[/b] The methodologies will advance the state-of-the-art in machine learning models and their applicability in the grant writing domain, as verified through testing and statistical analysis.
[b][i]i. Rationale[/i][/b]
This objective is crucial for the innovation of our project as it involves developing new methodologies that can improve the AI assistant's performance. The chosen acceptance criterion provides a measurable and relevant way to assess the methodologies' effectiveness, ensuring that they meet the needs of our customers.

[b][i]ii. Experimental Design & Methods[/i][/b]
Our approach to achieving this objective involves a series of tasks, including collecting and analyzing historical grant data, developing the methodologies, integrating them into the AI assistant, testing their effectiveness, and performing statistical analysis. Each task will be led by our team's lead data scientist, who will also be responsible for data collection. No special equipment is needed for data collection.

[b][i]iii. Data Analysis & Interpretation[/i][/b]
The data collected during the testing phase will be interpreted through statistical analysis to assess the methodologies' effectiveness. This analysis will provide insights into the methodologies' ability to improve the AI assistant's performance, thereby determining if the objective has been met.

[b][i]iv. Potential Pitfalls / Alternative Approaches[/i][/b]
Potential risks include the methodologies not being as effective as expected. In case of such issues, alternative approaches such as refining the methodologies or developing new ones will be considered.

[b][i]v. Expected Outcomes[/i][/b]
Upon achieving this objective, we expect to have new methodologies that can improve the AI assistant's performance. This will significantly advance our project, making the AI assistant more effective and increasing its potential for success.

[b]Project Development Chart[/b]

Month 1-6: Develop a context-aware language processing system (Lead Data Scientist)
Month 7-12: Test and refine the language processing system (Lead Data Scientist)
Month 13-18: Integrate the language processing system into the AI assistant (Software Engineer)
Month 19-24: Develop and test new data-driven methodologies (Lead Data Scientist)
Month 25-30: Integrate the methodologies into the AI assistant (Software Engineer)
Month 31-36: Final testing and refinement of the AI assistant (Project Lead)


[b]6. REFERENCES CITED[/b]

    Provide a comprehensive listing of relevant references, including patent numbers and other relevant intellectual property citations. A list of References Cited must be uploaded into the system.

qinput:
[b]7. BROADER IMPACTS[/b]

[b]Economic Competitiveness[/b]

The proposed AI-based grant writing assistant has the potential to significantly enhance the economic competitiveness of the United States. With over $750 billion awarded annually in the US through grants, the market opportunity for our innovative solution is substantial. By streamlining the grant writing process, our technology can help non-profit organizations and academic institutions secure much-needed funding, thereby enabling them to make a greater impact in their respective fields. This aligns with NSF's mission of advancing science and engineering in service of society.

The AI-based grant writing assistant can potentially increase the success rate of grant applications, leading to more efficient allocation of resources and increased productivity in the non-profit and academic sectors. This can result in significant economic benefits, including job creation, increased research and development activities, and advancements in various fields that can contribute to the overall economic competitiveness of the United States.

[b]Partnerships between Academia and Industry[/b]

Our AI-based grant writing assistant can also enhance partnerships between academia and industry. By making the grant writing process more efficient and effective, our technology can facilitate collaborations between academic institutions and industry partners. These collaborations can lead to the development of innovative solutions to pressing societal problems, further driving economic growth and competitiveness.

Moreover, the data-driven methodologies used in our AI-based grant writing assistant can be applied to other areas, such as market research and strategic planning, further enhancing the potential for academia-industry partnerships. This can lead to increased knowledge transfer, fostering an environment of innovation and growth.

[b]STEM Workforce Development[/b]

The development and implementation of our AI-based grant writing assistant involve significant R&D work, including the development of a context-aware language processing system and data-driven methodologies. This presents an opportunity for STEM workforce development, as it requires a team of skilled researchers and developers.

Our project can contribute to the development of an American STEM workforce that is globally competitive by providing opportunities for researchers and developers to work on cutting-edge AI technology. This can lead to the development of valuable skills and expertise in areas such as natural language processing and machine learning, which are in high demand in today's technology-driven economy.
'''
  
# Data to be sent
data = {
    "email": "brian3000@gmail.com",
    "branch": "test",
    "debug": "True",
    "body" : body,
    "model_title" : "NSF SBIR",
   # "initialize_url" : 'https://grantedai.bubbleapps.io/version-test/api/1.1/wf/nsf_response/initialize',
    "project_id" : '1684180443986x590840930442674200',
    "response_id" : '1693423816936x471405162411345800',
    'section' : 'Project Summary'
}

# Send the POST request
response = requests.post(url, json=data, headers=headers)
print(response)
print(response.text)
# Out:
# <Response [200]>
# {
#     "status": "success",
#     "response": {}
# }
